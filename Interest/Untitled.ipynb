# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Input=pd.read_csv("refresh7.csv",sep=",")
df= Input.dropna()
df
# Out:
#     Provide_physical_therapy_to_people_recovering_from_an_injury  \
# 0                                               unsure
# 1                                     strongly dislike
# 2                                              dislike
# 3                                              dislike
# 4                                     strongly dislike
# ..                                                 ...
# 118                                            dislike
# 119                                            dislike
# 120                                   strongly dislike
# 121                                             unsure
# 122                                            dislike
#
#     Create_special_effects_for_movies/_edit_movies  \
# 0                                 strongly dislike
# 1                                          dislike
# 2                                          dislike
# 3                                          dislike
# ...

# %%
df.shape
# Out:
# (123, 52)

# %%
df.dtypes
# Out:
# Provide_physical_therapy_to_people_recovering_from_an_injury    object
# Create_special_effects_for_movies/_edit_movies                  object
# Give_career_guidance_to_people                                  object
# Manage_a_department_within_a_large_company                      object
# Manage_the_operations_of_a_hotel                                object
# Study_the_movement_of_planets                                   object
# Load_computer_software_into_a_large_computer_network            object
# Assemble_electronic_parts                                       object
# Compute_and_record_statistical_and_other_numerical_data         object
# Act_in_a_play                                                   object
# Study_space_travel                                              object
# Conduct_chemical_experiments                                    object
# Organize_and_schedule_office_meetings                           object
# ...

# %%
df.head(10)
# Out:
#   Provide_physical_therapy_to_people_recovering_from_an_injury  \
# 0                                             unsure
# 1                                   strongly dislike
# 2                                            dislike
# 3                                            dislike
# 4                                   strongly dislike
# 5                                             unsure
# 6                                   strongly dislike
# 7                                             unsure
# 8                                   strongly dislike
# 9                                             unsure
#
#   Create_special_effects_for_movies/_edit_movies  \
# 0                               strongly dislike
# 1                                        dislike
# 2                                        dislike
# 3                                        dislike
# 4                               strongly dislike
# 5                               strongly dislike
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123 entries, 0 to 122
# Data columns (total 52 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Provide_physical_therapy_to_people_recovering_from_an_injury  123 non-null    object
#  1   Create_special_effects_for_movies/_edit_movies                123 non-null    object
#  2   Give_career_guidance_to_people                                123 non-null    object
#  3   Manage_a_department_within_a_large_company                    123 non-null    object
#  4   Manage_the_operations_of_a_hotel                              123 non-null    object
#  5   Study_the_movement_of_planets                                 123 non-null    object
#  6   Load_computer_software_into_a_large_computer_network          123 non-null    object
# ...

# %%
from sklearn import tree

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['Career'],axis=1)
print(df.isnull().values.any())

X.head(20)
# Out:
# False
#    Provide_physical_therapy_to_people_recovering_from_an_injury  \
# 0                                              unsure
# 1                                    strongly dislike
# 2                                             dislike
# 3                                             dislike
# 4                                    strongly dislike
# 5                                              unsure
# 6                                    strongly dislike
# 7                                              unsure
# 8                                    strongly dislike
# 9                                              unsure
# 10                                            dislike
# 11                                   strongly dislike
# 12                                   strongly dislike
# 13                                               like
# 14                                             unsure
# 15                                               like
# ...

# %%
y=df['Career'].values
y
# Out:
# array(['professor or teacher', 'Science', 'Science',
#        'professor or teacher', 'professor or teacher',
#        'professor or teacher', 'Science', 'Science',
#        'professor or teacher', 'Science', 'Science',
#        'professor or teacher', 'professor or teacher', 'Science',
#        'Science', 'Science', 'Science', 'Arts', 'Arts',
#        'Finance and Accounts', 'Arts', 'professor or teacher',
#        'Finance and Accounts', 'Arts', 'Arts', 'Finance and Accounts',
#        'Finance and Accounts', 'Arts', 'Finance and Accounts',
#        'Finance and Accounts', 'Arts', 'Civil Services', 'Civil Services',
#        'Civil Services', 'Civil Services', 'Civil Services',
#        'Media and Entertainment', 'Media and Entertainment',
#        'Civil Services', 'Civil Services', 'Media and Entertainment',
#        'Civil Services', 'Civil Services', 'Media and Entertainment',
#        'Media and Entertainment', 'Media and Entertainment', 'Startup',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([16, 13, 13, 16, 16, 16, 13, 13, 16, 13, 13, 16, 16, 13, 13, 13, 13,
#         1,  1,  6,  1, 16,  6,  1,  1,  6,  6,  1,  6,  6,  1,  2,  2,  2,
#         2,  2, 11, 11,  2,  2, 11,  2,  2, 11, 11, 11, 15, 11, 15,  9,  9,
#         9, 15, 15,  9,  9, 15, 15,  9, 15,  9,  8,  8,  8,  8,  8,  8,  8,
#         7,  7,  7,  0,  7,  0,  7,  7,  0,  5,  0,  5,  7,  0,  5,  0,  5,
#         5, 10,  0,  5,  5, 14, 10, 14, 10, 10, 14, 10, 10, 14, 10, 14, 14,
#        14,  4,  4,  4,  4, 12, 12, 12, 12,  4, 12,  4, 12, 12,  3,  3,  3,
#         3,  3,  4,  3])

# %%
X.replace(to_replace ='strongly dislike',value = 1,inplace=True)
X.replace(to_replace ='dislike',value = 2,inplace=True)
X.replace(to_replace ='unsure',value = 3,inplace=True)
X.replace(to_replace ='like',value = 4,inplace=True)
X.replace(to_replace ='strongly like',value = 5,inplace=True)
X.head()
# Out:
#    Provide_physical_therapy_to_people_recovering_from_an_injury  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Create_special_effects_for_movies/_edit_movies  \
# 0                                               1
# 1                                               2
# 2                                               2
# 3                                               2
# 4                                               1
#
#    Give_career_guidance_to_people  Manage_a_department_within_a_large_company  \
# 0                               5                                           1
# 1                               1                                           2
# 2                               1                                           1
# ...

# %%
y
# Out:
# array([16, 13, 13, 16, 16, 16, 13, 13, 16, 13, 13, 16, 16, 13, 13, 13, 13,
#         1,  1,  6,  1, 16,  6,  1,  1,  6,  6,  1,  6,  6,  1,  2,  2,  2,
#         2,  2, 11, 11,  2,  2, 11,  2,  2, 11, 11, 11, 15, 11, 15,  9,  9,
#         9, 15, 15,  9,  9, 15, 15,  9, 15,  9,  8,  8,  8,  8,  8,  8,  8,
#         7,  7,  7,  0,  7,  0,  7,  7,  0,  5,  0,  5,  7,  0,  5,  0,  5,
#         5, 10,  0,  5,  5, 14, 10, 14, 10, 10, 14, 10, 10, 14, 10, 14, 14,
#        14,  4,  4,  4,  4, 12, 12, 12, 12,  4, 12,  4, 12, 12,  3,  3,  3,
#         3,  3,  4,  3])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
y_test
# Out:
# array([15,  4,  0,  4, 11,  2,  8, 15, 10,  0, 12,  2, 10,  3,  4,  3, 13,
#         5, 12,  9,  8,  0,  7,  1,  5])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold

# %%
regressor=DecisionTreeClassifier()
cv = KFold(n_splits=10, random_state=42, shuffle=False)

regressor.fit(X_train,y_train)
# Out:
# E:\don\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#print(X_test.iloc[0])
#print(y_test.iloc[0])
y_pred = regressor.predict(X_test)
y_pred
#regressor.score(X_test,y_test)
# Out:
# array([15,  4,  0,  4,  8,  2,  8, 15, 10,  9, 12,  2, 10,  3,  4,  8, 13,
#         5, 12,  9,  8,  0,  7,  1,  5])

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test,y_pred))
# Out:
# 0.88

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=20,criterion='entropy',random_state=51)
rf_classifier.fit(X_train,y_train)
y_pred_rf=rf_classifier.predict(X_test)
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.76

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test,y_pred))
# Out:
# 0.88

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=20,criterion='entropy',random_state=51)

# %%
rf_classifier.fit(X_train,y_train)
y_pred_rf=rf_classifier.predict(X_test)
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.76

# %%
import pickle
#with open('y_pred_pickle','wb') as f:
#   pickle.dump(y_pred,f)

# %%
filename = 'final_model.sav'
pickle.dump(regressor, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
y_pred = loaded_model.predict(X_test)
y_pred
# Out:
# array([15,  4,  0,  4,  8,  2,  8, 15, 10,  9, 12,  2, 10,  3,  4,  8, 13,
#         5, 12,  9,  8,  0,  7,  1,  5])

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.88
